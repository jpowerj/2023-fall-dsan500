# %% [markdown]
# ## Scraping *B'Tselem (בצלם)*'s Data on the Ethnic Cleansing of Palestine

# %% [markdown]
# ::: {.callout-tip title="Video and Notebook Links"}
#
# * <a href='https://georgetown.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=f866cbea-62c7-4bdf-abd9-b098005e6d26' target='_blank'>Click here to access the accompanying **video** for this writeup</a>
# * Since Selenium doesn't work very well with Colab, there is no "Open in Colab" link for this writeup, so instead you can <a href='https://github.com/jpowerj/dsan5000/blob/main/writeups/selenium/Web_Scraping_With_Selenium.ipynb' target='_blank'>click here to view/download the `.ipynb` file from GitHub</a>, in case you'd like to run or modify the code yourself.
# * Just as the [data-cleaning writeup](../eda-seaborn/THOR_EDA_with_Seaborn.ipynb){target='_blank'} linked to <a href='https://jjacobs.me/mdb/chomsky-hr2/' target='_blank'>Volume II of *The Political Economy of Human Rights*</a>, providing the full-on context for that dataset, here I'll provide a link to Ilan Pappe's <a href='https://jjacobs.me/mdb/ethnic-cleansing-of-palestine/' target='_blank'>*The Ethnic Cleansing of Palestine*</a>, which provides context for this dataset (e.g., for why I choose the phrase, and why the title here refers to, the "ethnic cleansing" of Palestine, over other possible descriptors)
#
# :::

# %% [markdown]
# What happens if we try to scrape data from the Israeli human rights organization B'Tselem (בצלם), by just straightforwardly making a GET request using the `requests` library in Python?

# %%
# Python built-in libraries
import time

# 3rd-party libraries
import requests
from bs4 import BeautifulSoup

# %%
data_url = "https://statistics.btselem.org/en/all-fatalities/by-date-of-incident/pal-by-israel-sec/all?section=overall&tab=overview&ageSensor=%220%2C5%22"

# %%
response = requests.get(data_url)
print(response.text)
# Out:
# <!doctype html><html lang="en"><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" href="/favicon.ico"><title>Btselem</title><link rel="preconnect" href="https://fonts.gstatic.com"><link href="https://fonts.googleapis.com/css2?family=Rubik:wght@400;700&family=Tajawal:wght@400;700&display=swap" rel="stylesheet"><link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@mdi/font@latest/css/materialdesignicons.min.css"><script src="https://code.jquery.com/jquery-3.2.1.min.js"></script><script src="/assets/jsmaps/jsmaps-libs.js"></script><script src="/assets/jsmaps/jsmaps-panzoom.js"></script><script src="/assets/jsmaps/jsmaps.min.js"></script><meta property="og:title" content="Database on fatalities and house demolitions">
# <meta property="og:description" content="Database on fatalities and house demolitions in the Occupied Territories and Israel in the context of the conflict">
# <meta property="og:image" content="https://statistics.btselem.org/assets/images/social/facebook-en.jpg">
# <meta property="og:url" content="https://statistics.btselem.org/en/all-fatalities/by-date-of-incident/pal-by-israel-sec/all?section=overall&tab=overview&ageSensor=%220%2C5%22">
# <meta name="twitter:title" content="Database on fatalities and house demolitions">
# <meta name="twitter:description" content="Database on fatalities and house demolitions in the Occupied Territories and Israel in the context of the conflict">
# <meta name="twitter:image" content="https://statistics.btselem.org/assets/images/social/twitter-en.jpg">
# <meta name="twitter:card" content="summary_large_image"><script async src="https://www.googletagmanager.com/gtag/js?id=G-VGEZ53EM0D"></script><script>window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-VGEZ53EM0D');</script><script defer="defer" src="/js/chunk-vendors.3e01cde5.js"></script><script defer="defer" src="/js/app.b7350bdf.js"></script><link href="/css/chunk-vendors.3eab00f8.css" rel="stylesheet"><link href="/css/app.670d8df0.css" rel="stylesheet"></head><body><div id="app"></div><noscript><strong>We're sorry but Btselem doesn't work properly without JavaScript enabled. Please enable it to continue.</strong></noscript></body></html>

# %% [markdown]
# So, it seems we'll have to finally bite the bullet and use **Selenium** to scrape this data, since Selenium allows us to scrape even pages where data is **dynamically generated** using JavaScript.

# %%
# Uncomment and run the following line to install selenium, if you're using pip rather than conda
#!pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (4.14.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from selenium) (2.0.5)
# Requirement already satisfied: trio~=0.17 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/jpj/Downloads/venv/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# And then the following test code will pop up a new externally-controlled Firefox window and automatically navigate to the Selenium homepage at `https://selenium.dev`, if you have both Selenium and the Firefox **driver** for your operating system installed

# %%
from selenium import webdriver

browser = webdriver.Firefox()
browser.get('http://selenium.dev/')

# %% [markdown]
# Now let's try with the actual site

# %%
browser = webdriver.Firefox()
browser.get(data_url)
time.sleep(0.1)

# %%
# Helper functions, executing lines of JavaScript code in the browser to help with scraping
def get_scroll_position(browser_obj):
    cur_y_pos = browser_obj.execute_script("return window.pageYOffset")
    return cur_y_pos
def scroll_to_bottom(browser_obj):
    browser_obj.execute_script("window.scrollTo(0,document.body.scrollHeight);")

# %%
# And use these helper functions
# Get initial y position
cur_y_pos = get_scroll_position(browser)
print(f"y position at start of code block: {cur_y_pos}")
# Perform a scroll
scroll_to_bottom(browser)
# Check whether we have scrolled more
y_pos_after_scroll = get_scroll_position(browser)
print(f"y position after scrolling: {y_pos_after_scroll}")
# Out:
# y position at start of code block: 69165.5
# y position after scrolling: 69165.5

# %%
# Get initial y position
prev_y_pos = get_scroll_position(browser)
print(f"Initial y position: {prev_y_pos}")
y_pos_after_scroll = None
done_scrolling = False
while not done_scrolling:
    time.sleep(0.5)
    scroll_to_bottom(browser)
    # Check whether we have scrolled more
    y_pos_after_scroll = get_scroll_position(browser)
    print(f"Y position after scroll: {y_pos_after_scroll}")
    if y_pos_after_scroll == prev_y_pos:
        done_scrolling = True
    else:
        prev_y_pos = y_pos_after_scroll
final_y_pos = get_scroll_position(browser)
print(f"y position, now that we're done scrolling: {final_y_pos}")
# Out:
# Initial y position: 12023
# Y position after scroll: 13805
# Y position after scroll: 20066
# Y position after scroll: 26381
# Y position after scroll: 32430
# Y position after scroll: 38536
# Y position after scroll: 44268
# Y position after scroll: 50087
# Y position after scroll: 56155
# Y position after scroll: 62404
# Y position after scroll: 68259
# Y position after scroll: 69165.5
# Y position after scroll: 69165.5
# y position, now that we're done scrolling: 69165.5

# %%
# Print the DOM (the html code of the page *after* elements have been dynamically
# loaded by JavaScript)
dom_content = browser.page_source

# %%
# And save this JavaScript-generated html code to our hard drive, using open() and .write()
with open("scraped_content.html", 'w', encoding='utf-8') as outfile:
    outfile.write(dom_content)

# %% [markdown]
# Now we can load this `.html` file locally (without even needing to access the web or use `requests` or anything), and parse it using `BeautifulSoup`:

# %%
with open("scraped_content.html", 'r', encoding='utf-8') as infile:
    raw_html = infile.read()
raw_html
# Out:
# '<html lang="en" dir="ltr"><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" href="/favicon.ico"><title>Database on fatalities and house demolitions</title><link rel="preconnect" href="https://fonts.gstatic.com"><link href="https://fonts.googleapis.com/css2?family=Rubik:wght@400;700&amp;family=Tajawal:wght@400;700&amp;display=swap" rel="stylesheet"><link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@mdi/font@latest/css/materialdesignicons.min.css"><script src="https://code.jquery.com/jquery-3.2.1.min.js"></script><script src="/assets/jsmaps/jsmaps-libs.js"></script><script src="/assets/jsmaps/jsmaps-panzoom.js"></script><script src="/assets/jsmaps/jsmaps.min.js"></script><meta property="og:title" content="Database on fatalities and house demolitions">\n<meta property="og:description" content="Database on fatalities and house demolitions in the Occupied Territories and Israel in the context of the conflict">\n<meta property="og:image" content="https://statistics.btselem.org/assets/images/social/facebook-en.jpg">\n<meta property="og:url" content="https://statistics.btselem.org/en/all-fatalities/by-date-of-incident/pal-by-israel-sec/all?section=overall&amp;tab=overview&amp;ageSensor=%220%2C5%22">\n<meta name="twitter:title" content="Database on fatalities and house demolitions">\n<meta name="twitter:description" content="Database on fatalities and house demolitions in the Occupied Territories and Israel in the context of the conflict">\n<meta name="twitter:image" content="https://statistics.btselem.org/assets/images/social/twitter-en.jpg">\n<meta name="twitter:card" content="summary_large_image"><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-VGEZ53EM0D"></script><script>window.dataLayer = window.dataLayer || [];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'js\', new Date());\n\n      gtag(\'config\', \'G-VGEZ53EM0D\');</script><script defer="defer" src="/js/chunk-vendors.3e01cde5.js"></script><script defer="defer" src="/js/app.b7350bdf.js"></script><link href="/css/chunk-vendors.3eab00f8.css" rel="stylesheet"><link href="/css/app.670d8df0.css" rel="stylesheet"><style data-emotion=""></style><style type="text/css" id="vuetify-theme-stylesheet">.v-application a { color: #2b8dff; }\n.v-application .primary {\n  background-color: #2b8dff !important;\n  border-color: #2b8dff !important;\n}\n.v-application .primary--text {\n  color: #2b8dff !important;\n  caret-color: #2b8dff !important;\n}\n.v-application .primary.lighten-5 {\n  background-color: #dcffff !important;\n  border-color: #dcffff !important;\n}\n.v-application .primary--text.text--lighten-5 {\n  color: #dcffff !important;\n  caret-color: #dcffff !important;\n}\n.v-application .primary.lighten-4 {\n  background-color: #bcfaff !important;\n  border-color: #bcfaff !important;\n}\n.v-application .primary--text.text--lighten-4 {\n  color: #bcfaff !important;\n  caret-color: #bcfaff !important;\n}\n.v-application .primary.lighten-3 {\n  background-color: #9ddeff !important;\n  border-color: #9ddeff !important;\n}\n.v-application .primary--text.text--lighten-3 {\n  color: #9ddeff !important;\n  caret-color: #9ddeff !important;\n}\n.v-application .primary.lighten-2 {\n  background-color: #7cc2ff !important;\n  border-color: #7cc2ff !important;\n}\n.v-application .primary--text.text--lighten-2 {\n  color: #7cc2ff !important;\n  caret-color: #7cc2ff !important;\n}\n.v-application .primary.lighten-1 {\n  background-color: #58a7ff !important;\n  border-color: #58a7ff !important;\n}\n.v-application .primary--text.text--lighten-1 {\n  color: #58a7ff !important;\n  caret-color: #58a7ff !important;\n}\n.v-application .primary.darken-1 {\n  background-color: #0074e2 !important;\n  border-color: #0074e2 !important;\n}\n.v-application .primary--text.text--darken-1 {\n  color: #0074e2 !important;\n  caret-color: #0074e2 !important;\n ...

# %%
# We can use BeautifulSoup to parse this Selenium-scraped html code just like we
# used it to parse "static" html code obtained using the requests library.
soup = BeautifulSoup(raw_html)

# %%
# Get objects representing the 334 `<div>` elements on the page which have
# class="v-list-item__content" (the class we found for each data box using
# the inspector in Firefox)
content_elts = soup.find_all("div", {'class': 'v-list-item__content'})
len(content_elts)
# Out:
# 334

# %% [markdown]
# Now that we have these 334 individual data "boxes", we loop through them and extract the individual pieces of data within each one: the child's name, the textual description of their murder, and the name of the military operation in which they were killed

# %%
content_elts = soup.find_all("div", {'class': 'v-list-item__content'})
all_data = []
for cur_elt in content_elts:
    elt_headline = cur_elt.find("div", {'class': 'headline'})
    cur_name = elt_headline.text
    elt_main_text = cur_elt.find("p").text
    #print(elt_main_text)
    elt_badge = cur_elt.find("span")
    badge_text = ""
    if elt_badge is not None:
        print(f"Badge content: {elt_badge.text}")
        badge_text = elt_badge.text
    cur_data = {
        'name': cur_name,
        'text': elt_main_text,
        'badge_text': badge_text
    }
    all_data.append(cur_data)
# Out:
# Badge content:  Military operation: Shield and Arrow
# Badge content:  Military operation: Breaking Dawn
# Badge content:  Military operation: Breaking Dawn
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Guardian of the Walls
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Protective Edge
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Pillar of Defense
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Cast Lead
# Badge content:  Military operation: Defensive Shield

# %% [markdown]
# Now, since at the end of each loop iteration we created a **Python dictionary** with keys `name`, `text`, and `badge_text`, and added it as an element of `all_data`, we can look at any of the elements within `all_data` and know that it will have the name, text, and military operation info for that child:

# %%
all_data[0]
# Out:
# {'name': 'Muhammad Haitham Ibrahim Tamimi',
#  'text': '2-year-old resident of a-Nabi Saleh, Ramallah and al-Bira District, injured on June 1, 2023, in a-Nabi Saleh, Ramallah and al-Bira District,  live ammunition, and died on June 5, 2023.  Additional information: Wounded in the head by soldiers’ gunfire together with his father, who was wounded in the shoulder, when the two were sitting in their car waiting to depart for a family visit.  [More Info] ',
#  'badge_text': ''}

# %% [markdown]
# The main reason to create these Python dictionaries within each for loop iteration, however, is that this format is immediately "recognized" by Pandas, so that we can pass our list of dictionaries `all_data` directly into the `pd.DataFrame()` constructor to generate a full `DataFrame` object containing all of our data, with the correct headers based on the dictionary keys:

# %%
import pandas as pd

# %%
scraped_data_df = pd.DataFrame(all_data)
scraped_data_df
# Out:
#                                 name  \
# 0    Muhammad Haitham Ibrahim Tamimi
# 1      Hajar Khalil Salah al-Bahtini
# 2       Jamil Najm a-Din Jamil Nijem
# 3         Alaa 'Abdallah Riyad Qadum
# 4         Qusai Sameh Fawaz al-Kolak
# ..                               ...
# 329            'Azzam Samir a-Sha'bi
# 330                   Riham Abu Taha
# 331           Shaimaa 'Imad al-Masri
# 332                Burhan al-Haymuni
# 333               Iman Muhammad Hiju
#
#                                                   text  \
# 0    2-year-old resident of a-Nabi Saleh, Ramallah ...
# 1    4 year old resident of Gaza city, Gaza Distric...
# 2    3 year old resident of Jabalya R.C., North Gaz...
# 3    5 year old resident of Gaza city, Gaza Distric...
# 4    Under 1 year old resident of Gaza city, Gaza D...
# ..                                                 ...
# 329  3 year old resident of Nablus, killed on April...
# 330  4 year old resident of Tall a-Sultan Camp, Raf...
# 331  4 year old resident of Ramallah, Ramallah and ...
# 332  3 year old resident of Hebron, killed on Decem...
# 333  Under 1 year old resident of Khan Yunis, kille...
#
#                                       badge_text
# 0
# 1          Military operation: Shield and Arrow
# 2             Military operation: Breaking Dawn
# 3             Military operation: Breaking Dawn
# 4     Military operation: Guardian of the Walls
# ..                                           ...
# 329        Military operation: Defensive Shield
# 330
# 331
# 332
# 333
#
# [334 rows x 3 columns]

# %% [markdown]
# And finally, just like any other Pandas `DataFrame` object, we can use Pandas' `to_csv()` function to save this structured dataset to our hard drive:

# %%
scraped_data_df.to_csv("parsed_data.csv")

# %% [markdown]
# ## Scraping Amnesty International's Countries Page
#
# [This page](https://www.amnesty.org/en/countries/) has a bit of a different structure, where we'll have to interact with the page in a different way from just scrolling. For example, right when we load the page we see an "Accept Cookies" dialog, and then once we're past that it looks like we'll need to click each individual letter "A", "B", "C", etc., to get the links to Amnesty's pages on countries starting with these letters
#
# *(We'll see that, at the end of the day, we actually don't need to do all this clicking, but I'm including this part so that you know how to **programmatically click things in a page** using Selenium)*

# %%
browser = webdriver.Firefox()
browser.get(data_url)
time.sleep(0.1)

# %%
amnesty_url = "https://www.amnesty.org/en/countries/"

# %%
browser.get(amnesty_url)

# %% [markdown]
# Using the "By" syntax in Selenium: This `By` object that we import in the next cell allows us to **tell Selenium *how* we're selecting elements on the page**: for example, by the element(s) ID values, by the text of a link, or some other property of the text/button/link/heading/etc.

# %%
from selenium.webdriver.common.by import By

# %% [markdown]
# So, first we tell Selenium that we'd like to select elements by their **id** property, and then we specifically select the **Accept Cookies** button, which we found (using the Inspector panel in Firefox) has the id value `"ccc-notify-accept"`

# %%
accept_button = browser.find_element(By.ID, 'ccc-notify-accept')

# %%
accept_button.click()

# %% [markdown]
# Now that we've clicked the "Accept Cookies" button, here we'll start with some code that will allow us to click the "Z" button at the top of the page, revealing the countries in Amnesty's database which start with the letter "Z":

# %%
Z_button = browser.find_element(By.XPATH, "//button[text()='Z']")

# %%
Z_button.click()

# %% [markdown]
# However (as I talk about more in the video), the way this webpage is designed actually makes it easier for us to scrape, since it turns out that **all of the links for all of the countries** are loaded into the page at the beginning of when it is loaded, and then **subsequently** all of the links besides the countries for the currently-selected letter are **hidden** using the CSS value `display: none`.
#
# What this means is that we don't even need to click on the letters programmatically: we can just get all of the `<a>` elements which exist (even if hidden) within the `<div>` element on the page containing the list of countries:

# %%
country_link_container = browser.find_element(By.CLASS_NAME, "listContainer")

# %%
country_links = country_link_container.find_elements(By.TAG_NAME, "a")

# %% [markdown]
# And the following code tells us that Amnesty lists 157 countries in total:

# %%
len(country_links)
# Out:
# 157

# %%
first_country_link = country_links[31]

# %%
first_country_link.get_property("href")
# Out:
# 'https://www.amnesty.org/en/location/europe-and-central-asia/croatia/'

# %% [markdown]
# Here, however, the following two code blocks show that there's a bit of a tricky approach we have to take if we want to get the text content of elements which are **hidden** on the actual displayed page in your browser. In the following cell, we see that just accessing the `.text` attribute on a country link will **not** produce the name of the country when the country's link is hidden:

# %%
first_country_link.text
# Out:
# ''

# %% [markdown]
# **But**, we can use a trick here, which is that even when elements which are not visible on the page they will still have an attribute called `textContent`, so that if we access **this** attribute of the link (rather than the simpler `.text` attribute), we can in fact get the text that **would** be displayed **if** the element was not hidden:

# %%
first_country_link.get_attribute("textContent")
# Out:
# 'Croatia'

# %% [markdown]
# And now, just like before, we make sure to create a **Python dictionary** at the end of each loop iteration, containing all of the data we've extracted from the element we were looking at in that loop iteration, so that it will be easy to create a Pandas `DataFrame` once we the loop has finished running:

# %%
all_data = []
for cl in country_links:
    country_url = cl.get_property('href')
    country_name = cl.get_attribute('textContent')
    country_data = {
        'name': country_name,
        'url': country_url
    }
    all_data.append(country_data)

# %% [markdown]
# So here we note that creating these dictionary objects in each loop iteration makes it easy to view individual records:

# %%
all_data[50]
# Out:
# {'name': 'Gambia',
#  'url': 'https://www.amnesty.org/en/location/africa/west-and-central-africa/gambia/'}

# %%
[(cl.get_property("href"), cl.get_attribute("textContent")) for cl in country_links]
# Out:
# [('https://www.amnesty.org/en/location/asia-and-the-pacific/south-asia/afghanistan/',
#   'Afghanistan'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/albania/',
#   'Albania'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/algeria/',
#   'Algeria'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/andorra/',
#   'Andorra'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/angola/',
#   'Angola'),
#  ('https://www.amnesty.org/en/location/americas/south-america/argentina/',
#   'Argentina'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/armenia/',
#   'Armenia'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/australia/',
#   'Australia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/austria/',
#   'Austria'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/azerbaijan/',
#   'Azerbaijan'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/bahrain/',
#   'Bahrain'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-asia/bangladesh/',
#   'Bangladesh'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/belarus/',
#   'Belarus'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/belgium/',
#   'Belgium'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/benin/',
#   'Benin'),
#  ('https://www.amnesty.org/en/location/americas/south-america/bolivia/',
#   'Bolivia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/bosnia-and-herzegovina/',
#   'Bosnia and Herzegovina'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/botswana/',
#   'Botswana'),
#  ('https://www.amnesty.org/en/location/americas/south-america/brazil/',
#   'Brazil'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/bulgaria/',
#   'Bulgaria'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/burkina-faso/',
#   'Burkina Faso'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/burundi/',
#   'Burundi'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/cambodia/',
#   'Cambodia'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/cameroon/',
#   'Cameroon'),
#  ('https://www.amnesty.org/en/location/americas/north-america/canada/',
#   'Canada'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/central-african-republic/',
#   'Central African Republic'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/chad/',
#   'Chad'),
#  ('https://www.amnesty.org/en/location/americas/south-america/chile/',
#   'Chile'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/east-asia/china/',
#   'China'),
#  ('https://www.amnesty.org/en/location/americas/south-america/colombia/',
#   'Colombia'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/congo/',
#   'Congo'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/croatia/',
#   'Croatia'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/cuba/',
#   'Cuba'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/cyprus/',
#   'Cyprus'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/czech-republic/',
#   'Czech Republic'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/cote-divoire/',
#   "Côte d'Ivoire"),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/democratic-republic-of-the-congo/',
#   'Democratic Republic of the Congo'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/denmark/',
#   'Denmark\xa0'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/dominican-republic/',
#   'Dominican Republic'),
#  ('https://www.amnesty.org/en/location/americas/south-america/ecuador/',
#   'Ecuador'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/egypt/',
#   'Egypt'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/el-salvador/',
#   'El Salvador'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/equatorial-guinea/',
#   'Equatorial Guinea'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/eritrea/',
#   'Eritrea'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/estonia/',
#   'Estonia'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/eswatini/',
#   'Eswatini'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/ethiopia/',
#   'Ethiopia'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/fiji/',
#   'Fiji'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/finland/',
#   'Finland'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/france/',
#   'France'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/gambia/',
#   'Gambia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/georgia/',
#   'Georgia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/germany/',
#   'Germany'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/ghana/',
#   'Ghana'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/greece/',
#   'Greece'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/guatemala/',
#   'Guatemala'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/guinea/',
#   'Guinea'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/haiti/',
#   'Haiti'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/honduras/',
#   'Honduras'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/hungary/',
#   'Hungary'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/iceland/',
#   'Iceland'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-asia/india/',
#   'India'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/indonesia/',
#   'Indonesia'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/iran/',
#   'Iran'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/iraq/',
#   'Iraq'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/ireland/',
#   'Ireland'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/israel-and-occupied-palestinian-territories/',
#   'Israel and Occupied Palestinian Territories'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/italy/',
#   'Italy'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/east-asia/japan/',
#   'Japan'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/jordan/',
#   'Jordan'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/kazakhstan/',
#   'Kazakhstan'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/kenya/',
#   'Kenya'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/kosovo/',
#   'Kosovo'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/kuwait/',
#   'Kuwait'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/kyrgyzstan/',
#   'Kyrgyzstan'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/laos/',
#   'Laos'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/latvia/',
#   'Latvia'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/lebanon/',
#   'Lebanon'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/lesotho/',
#   'Lesotho'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/libya/',
#   'Libya'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/lithuania/',
#   'Lithuania'),
#  ('https://www.amnesty.org/en/location/laos-2/', 'laos'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/madagascar/',
#   'Madagascar'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/malawi/',
#   'Malawi'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/malaysia/',
#   'Malaysia'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-asia/maldives/',
#   'Maldives'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/mali/',
#   'Mali'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/malta/',
#   'Malta'),
#  ('https://www.amnesty.org/en/location/americas/north-america/mexico/',
#   'Mexico'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/moldova/',
#   'Moldova'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/east-asia/mongolia/',
#   'Mongolia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/montenegro/',
#   'Montenegro'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/morocco-and-western-sahara/',
#   'Morocco and Western Sahara'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/mozambique/',
#   'Mozambique'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/myanmar/',
#   'Myanmar'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/namibia/',
#   'Namibia'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-asia/nepal/',
#   'Nepal'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/netherlands/',
#   'Netherlands'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/new-zealand/',
#   'New Zealand'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/nicaragua/',
#   'Nicaragua'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/niger/',
#   'Niger'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/nigeria/',
#   'Nigeria'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/east-asia/north-korea/',
#   'North Korea'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/north-macedonia/',
#   'North Macedonia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/norway/',
#   'Norway'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/oman/',
#   'Oman'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-asia/pakistan/',
#   'Pakistan'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/palestine-state-of/',
#   'Palestine (State of)'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/papua-new-guinea/',
#   'Papua New Guinea'),
#  ('https://www.amnesty.org/en/location/americas/south-america/paraguay/',
#   'Paraguay'),
#  ('https://www.amnesty.org/en/location/americas/south-america/peru/', 'Peru'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/philippines/',
#   'Philippines'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/poland/',
#   'Poland'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/portugal/',
#   'Portugal'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/puerto-rico/',
#   'Puerto Rico'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/qatar/',
#   'Qatar'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/romania/',
#   'Romania'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/russia/',
#   'Russia'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/rwanda/',
#   'Rwanda'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/saudi-arabia/',
#   'Saudi Arabia'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/senegal/',
#   'Senegal'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/serbia/',
#   'Serbia'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/sierra-leone/',
#   'Sierra Leone'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/singapore/',
#   'Singapore'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/slovakia/',
#   'Slovakia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/slovenia/',
#   'Slovenia'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/somalia/',
#   'Somalia'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/south-africa/',
#   'South Africa'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/east-asia/south-korea/',
#   'South Korea'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/south-sudan/',
#   'South Sudan'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/spain/',
#   'Spain'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-asia/sri-lanka/',
#   'Sri Lanka'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/sudan/',
#   'Sudan'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/sweden/',
#   'Sweden'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/switzerland/',
#   'Switzerland'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/syria/',
#   'Syria'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/east-asia/taiwan/',
#   'Taiwan'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/tajikistan/',
#   'Tajikistan'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/tanzania/',
#   'Tanzania'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/thailand/',
#   'Thailand'),
#  ('https://www.amnesty.org/en/location/africa/west-and-central-africa/togo/',
#   'Togo'),
#  ('https://www.amnesty.org/en/location/americas/central-america-and-the-caribbean/trinidad-and-tobago/',
#   'Trinidad and Tobago'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/tunisia/',
#   'Tunisia'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/turkmenistan/',
#   'Turkmenistan'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/turkey/',
#   'Türkiye'),
#  ('https://www.amnesty.org/en/location/africa/east-africa-the-horn-and-great-lakes/uganda/',
#   'Uganda'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/ukraine/',
#   'Ukraine'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/united-arab-emirates/',
#   'United Arab Emirates'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/united-kingdom/',
#   'United Kingdom'),
#  ('https://www.amnesty.org/en/location/americas/north-america/united-states-of-america/',
#   'United States of America'),
#  ('https://www.amnesty.org/en/location/americas/south-america/uruguay/',
#   'Uruguay'),
#  ('https://www.amnesty.org/en/location/europe-and-central-asia/uzbekistan/',
#   'Uzbekistan'),
#  ('https://www.amnesty.org/en/location/americas/south-america/venezuela/',
#   'Venezuela'),
#  ('https://www.amnesty.org/en/location/asia-and-the-pacific/south-east-asia-and-the-pacific/viet-nam/',
#   'Viet Nam'),
#  ('https://www.amnesty.org/en/location/middle-east-and-north-africa/yemen/',
#   'Yemen'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/zambia/',
#   'Zambia'),
#  ('https://www.amnesty.org/en/location/africa/southern-africa/zimbabwe/',
#   'Zimbabwe')]

# %% [markdown]
# Plus makes it easy to "plug" the list of dictionary objects into the `pd.DataFrame()` constructor to quickly create a well-structured dataset:

# %%
country_df = pd.DataFrame(all_data)
country_df
# Out:
#             name                                                url
# 0    Afghanistan  https://www.amnesty.org/en/location/asia-and-t...
# 1        Albania  https://www.amnesty.org/en/location/europe-and...
# 2        Algeria  https://www.amnesty.org/en/location/middle-eas...
# 3        Andorra  https://www.amnesty.org/en/location/europe-and...
# 4         Angola  https://www.amnesty.org/en/location/africa/sou...
# ..           ...                                                ...
# 152    Venezuela  https://www.amnesty.org/en/location/americas/s...
# 153     Viet Nam  https://www.amnesty.org/en/location/asia-and-t...
# 154        Yemen  https://www.amnesty.org/en/location/middle-eas...
# 155       Zambia  https://www.amnesty.org/en/location/africa/sou...
# 156     Zimbabwe  https://www.amnesty.org/en/location/africa/sou...
#
# [157 rows x 2 columns]

# %% [markdown]
# Which we could then save just like we saved the B'Tselem data before, using Pandas' `.to_csv()` function:

# %%
country_df.to_csv("amnesty_countries.csv")
